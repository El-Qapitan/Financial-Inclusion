# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('Train.csv')

# %%
df
# Out:
#       country  year       uniqueid bank_account location_type  \
# 0       Kenya  2018     uniqueid_1          Yes         Rural
# 1       Kenya  2018     uniqueid_2           No         Rural
# 2       Kenya  2018     uniqueid_3          Yes         Urban
# 3       Kenya  2018     uniqueid_4           No         Rural
# 4       Kenya  2018     uniqueid_5           No         Urban
# ...       ...   ...            ...          ...           ...
# 23519  Uganda  2018  uniqueid_2113           No         Rural
# 23520  Uganda  2018  uniqueid_2114           No         Rural
# 23521  Uganda  2018  uniqueid_2115           No         Rural
# 23522  Uganda  2018  uniqueid_2116           No         Urban
# 23523  Uganda  2018  uniqueid_2117           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 0                  Yes               3                 24
# 1                   No               5                 70
# ...

# %%
label = LabelEncoder()
label.fit(df.bank_account.drop_duplicates())
df.bank_account = label.transform(df.bank_account)

label.fit(df.location_type.drop_duplicates())
df.location_type = label.transform(df.location_type)

label.fit(df.cellphone_access.drop_duplicates())
df.cellphone_access = label.transform(df.cellphone_access)

label.fit(df.gender_of_respondent.drop_duplicates())
df.gender_of_respondent = label.transform(df.gender_of_respondent)

label.fit(df.marital_status.drop_duplicates())
df.marital_status = label.transform(df.marital_status)

df.head()
# Out:
#   country  year    uniqueid  bank_account  location_type  cellphone_access  \
# 0   Kenya  2018  uniqueid_1             1              0                 1
# 1   Kenya  2018  uniqueid_2             0              0                 0
# 2   Kenya  2018  uniqueid_3             1              1                 1
# 3   Kenya  2018  uniqueid_4             0              0                 1
# 4   Kenya  2018  uniqueid_5             0              1                 0
#
#    household_size  age_of_respondent  gender_of_respondent  \
# 0               3                 24                     0
# 1               5                 70                     0
# 2               5                 26                     1
# 3               5                 34                     0
# 4               8                 26                     1
#
#   relationship_with_head  marital_status                  education_level  \
# 0                 Spouse               2              Secondary education
# ...

# %%
df.tail()
# Out:
#       country  year       uniqueid  bank_account  location_type  \
# 23519  Uganda  2018  uniqueid_2113             0              0
# 23520  Uganda  2018  uniqueid_2114             0              0
# 23521  Uganda  2018  uniqueid_2115             0              0
# 23522  Uganda  2018  uniqueid_2116             0              1
# 23523  Uganda  2018  uniqueid_2117             0              0
#
#        cellphone_access  household_size  age_of_respondent  \
# 23519                 1               4                 48
# 23520                 1               2                 27
# 23521                 1               5                 27
# 23522                 1               7                 30
# 23523                 1              10                 20
#
#        gender_of_respondent relationship_with_head  marital_status  \
# 23519                     0      Head of Household               0
# 23520                     0      Head of Household               3
# ...

# %%
x_lin = df.drop(['bank_account', 'country', 'uniqueid', 'relationship_with_head', 'education_level', 'job_type'], axis = 1)
y_lin = df[['bank_account']]

x_lin_train, x_lin_test, y_lin_train, y_lin_test = train_test_split(x_lin, y_lin, test_size = 0.3, random_state = 40)

Linear_model = LinearRegression()
Linear_model.fit(x_lin_train, y_lin_train)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(x_lin_train.columns):
    print('coefficient for {} is {}'.format(col_name, Linear_model.coef_[0][idx]))
# Out:
# coefficient for year is 0.041561285646503784
# coefficient for location_type is 0.05361721999299085
# coefficient for cellphone_access is 0.1730567064698229
# coefficient for household_size is -0.00486943012777363
# coefficient for age_of_respondent is 0.0011393303812281736
# coefficient for gender_of_respondent is 0.06408257048327343
# coefficient for marital_status is -0.008453769348474683

# %%
intercept = Linear_model.intercept_[0]
intercept
# Out:
# -83.86978443300039

# %%
y_pred = Linear_model.predict(x_lin_test)
pred = pd.DataFrame(x_lin_test)
pred['bank_account'] = y_lin_test
pred['predbank_account'] = y_pred
pred
# Out:
#        year  location_type  cellphone_access  household_size  \
# 19871  2017              1                 0               1
# 753    2018              1                 1               6
# 14299  2016              0                 1               3
# 10351  2016              0                 1               1
# 16785  2017              1                 1               5
# ...     ...            ...               ...             ...
# 4104   2018              0                 0               3
# 4974   2018              1                 1               4
# 8692   2016              0                 1               7
# 5792   2018              0                 1               4
# 19366  2017              1                 0               2
#
#        age_of_respondent  gender_of_respondent  marital_status  bank_account  \
# 19871                 40                     0               2             0
# ...

# %%
Linear_model.score(x_lin_test, y_lin_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1048/160711616.py in <module>
# ----> 1 Linear_model.score(x_lin_test, y_lin_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
# ...
